# %% [markdown]
# <a href="https://colab.research.google.com/github/Vipinkthomas/Machin-Leaning-Resources/blob/SVM_CNN/Workspace.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 3

# %% [markdown]
# ### Introduction
#
# In the production of electrical drives, a high product quality is needed. As the industry of electric drive production is confronted by trends such as electric mobility and continuing industrial automation, efficient and flexible processes are needed more than ever. With current quality monitoring technology, accurate quality checking is not feasible.
#
# Electrical motors mainly consist of the rotor, the stator and the surrounding housing. The production process can be separated into multiple sub-processes, which can be seen below. The exact sequence of these steps however depends on the motor type. First, the individual components are manufactured and assembled into subassemblies such as the rotor and the stator. Finally, all components (the housing, the stator, the rotor as well as bearings and end shields) are assembled and the motor is checked in an end-of-line (EOL) test.
#
# This final assembly is of great importance, as all parts need to be assembled in the correct way, to ensure smooth operation. Therefore, a quality monitoring system is needed, raising alarm if assembly errors are detected. However, especially in lot-size one production, traditional computer vision systems might reach their limits and cannot be used anymore.
#
# Thus, in this lab we will build a smart quality monitoring system for the electric drives production. An already existing visual sensor captures images of the electric motor after assembly. These images show the part from the top, as well from the side perspective. It is now the target to decide whether the motor is fully assembled, or whether one of multiple defects is present. There is data from three different defects available: *missing cover*, *missing screw* and *not screwed*. Examples of these defects can be seen below. To achieve this, we will investigate two different machine learning models: *Support Vector Machines* (SVM) and *Convolutional Neural Networks* (CNN).
#
# Further background information can be found in this paper: [Mayr et al., Machine Learning in Electric Motor Production - Potentials, Challenges and Exemplary Applications](https://ieeexplore.ieee.org/document/9011861)
#
# ![Introduction](https://github.com/Vipinkthomas/Machin-Leaning-Resources/blob/SVM_CNN/img/Intro_dataset.png?raw=1)

# %% [markdown]
# #### Outline
# This lab is structured into two main parts. In the **first part**, a subset of the problem will be analyzed step-by-step. Here, only images from the top view are used and only two of the three defects, the defects *missing cover* and *missing screw* are considered. Your task will be to follow along, fill out missing gaps, and answer problems throughout the notebook.
#
# In the **second part**, you are tasked to expand the quality monitoring system to also detect the defect *not screwed*. Therefore, it might be helpful to also consider images showing the parts in their side perspective. For this part, you are free to choose any of the tools and methods introduced in the first part, and you can expand as you wish!
#
# #### Deliverables
# For completing this exercise successfully, you need to deliver certain results. Throughout the notebook you will find **questions** you need to answer, and coding **tasks** where you need to modify existing code or fill in blanks. Answers to the questions need to be added in the prepared *Your answer here* markdown fields. Coding tasks can be solved by modifying or inserting code in the cells below the task. If needed, you can add extra cells to the notebook, as long as the order of the existing cells remains unchanged. Once you are finished with the lab, you can submit it through the procedure described in the forum. Once the labs are submitted, you will receive feedback regarding the questions. Thus, the **Feedback** boxes need to be left empty
#
# Example:
#
# >**Question:** What do I do if I am stuck solving this lab?
#
# >**Your answer:** <span style="color:green">Have a look at the forum, maybe some of your peers already experienced similiar issues. Otherwise start a new discussion to get help!</span>
#
# >**Feedback:** <span style="color:orange">This is a great approach! Besides asking in the forum I'd also suggest asking your tutor.</span>
#
# #### Ressources
# If you are having issues while completing this lab, feel free to post your questions into the forum. Your peers as well as our teaching advisors will screen the forum regularly and answer open questions. This way, the information is available for fellow students encountering the same issues.

# %%
# Mount your GDrive - Authentication required - Please follow the instructions
from google.colab import drive
from google.colab.patches import cv2_imshow
import sys, os
drive.mount('/content/gdrive')

# Change the current working directory

# Depending on your directory, you may want to adjust this
dir_path = '/content/gdrive/My Drive/ML4Eng_I/'
sys.path.append(dir_path)
os.chdir(dir_path)
# Out:
# Mounted at /content/gdrive

# %%
# As in the previous exercises, we'll import commonly used libraries right at the start
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2
import random
import tensorflow as tf
# The check.py script contains the quality gates you can use for selftesting throughout the lab
from scripts.check import *

# %% [markdown]
# ## 1 Part one
# To achieve the solution mentioned above, we will execute the following steps in this lab:
#
# 1. First, we will code the necessary functions for loading and preprocessing of the data. We will also set up some methods that help us displaying our progress throughout the exercise
# 2. Second, we will do a short analysis of the existing dataset
# 3. Afterwards, we will start building our first image classification model using SVMs
# 4. Once we are familiar and comfortable with SVMs, we will switch to neural networks and try out CNNs
# 5. Finally, we will introduce data augmentation for improvement of our prediction results.

# %% [markdown]
# ## Section 1.1: Data preprocessing
# The data should be located in the folder called *data* on the same level as this script. Within this folder, two subfolders can be found:
# - The folder **top** contains the top view of each motor
# - The folder **side** contains the side view of each motor
#
# Each motor is uniquely identified by its filename.

# %%
# Loading one image in top view
path = "./data/top/L1_C_3.JPG"
img = cv2.imread(path)
img.shape
# Out:
# (1024, 1024, 3)

# %% [markdown]
# With the snippet above, we are able to load the image from the file into a numpy array, while getting its label from the folder path the image is in.
# To check the type of a python object, you can use the command `type(img)`. It should return *numpy.ndarray*.

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.title(path.split('/')[-1]) # title of the plot
plt.imshow(img) # display image
plt.axis('off') # axis off
plt.show()

# %% [markdown]
# Next, we want to plot the image. This can be achieved by executing the following cell.

# %% [markdown]
# By default, open cv assumes the images are encoded in blue, green and red. However, the actual order of the color channels is blue, red and green. Thus, the channels need to be converted using `cv2.COLOR_BGR2RGB`.

# %%
"""
imread openCV funciton conver image in to BGR format so to chnage it back to normal RGB format use cvtColor function

"""

img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB) # covert OpenCV color format to pillow or normal format
plt.title(path.split('/')[-1]) # title of the plot
plt.imshow(img) # display image
plt.axis('off') # axis off
plt.show()

# %% [markdown]
# #### Function for loading multiple images
# Now it's your turn. For the further analysis, we need to load all the available images from the given data folder *folder*. Besides the image, we need to also find the class of the respective image. The information of the class is encoded in the title of each image. You can use the helper function `get_label_from_name(path)` to parse the filename to the class.
#
# >**Task:** Please complete the following function **load_features_labels(folder)**. The function should read the image for a given file, and return two lists:
# >- *features* containing all the images as numpy arrays
# >- *labels* containing the classes of all images

# %%
import glob
def get_label_from_name(path):

  if "_C_" in path:
    return "Complete"
  if "_MC_" in path:
    return "Missing cover"
  if "_MS_" in path:
    return "Missing screw"
  if "_NS_" in path:
    return "Not screwed" 
  raise Exception("sorry, please label"+path+"file") # raise exception for outclass identifiers
  
def load_features_labels(folder,identifiers=['NS', 'MS', 'MC', 'C']):
  features=[]
  labels=[]
  for path in glob.glob(folder+'/*.JPG'):

    if any(identifier in path for identifier in identifiers): 
      labels.append(get_label_from_name(path))
    img=cv2.imread(path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    features.append(img)

  return features, labels

# %% [markdown]
# If everything works as expected, the function should load 117 features and labels. The execution may take a while.

# %%
features, labels = load_features_labels("./data/top")
print("Number of features:", len(features))
print("Number of labels:", len(labels))

# Check data import
quality_gate_111(features, labels)
# Out:
# Number of features: 117
# Number of labels: 117
# 'Quality gate passed :)'

# %% [markdown]
# #### Image preprocessing
# Before analyzing the images using machine learning, they need to be preprocessed. We will do preprocessing regarding three aspects:
# - **Image size**: As the raw images are available in rather high resolution, it might be beneficial to reduce the image resolution. Opencv provides the function `resize()` which works great for that purpose
# - **Image color**: In many use cases, the benefit of considering color information might not outway the increased complexity, thus it might be handy to convert the rgb image to bw. This can easily be done using the `cvtColor` function from opencv.
# - **Image shape**: Only some algorithms are capable of analyzing the 2.5D structure of image data. For the remaining algorithms, which expect the data to be 1D vector, the image data needs to be flattened from 2.5D to 1D. This can be done using the numpy `reshape` functionality.

# %%
def image_preprocessing(img,size=(64,32),flatten= True,color=False):
  img=cv2.resize(img,size)
  if not color:
    img=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
  if flatten:
    img=img.reshape(-1) # or img.reshape(1,-1) or reshape(1,6)
  return img

# %% [markdown]
# >**Task:** Please update your `load_features_labels(...)` function from above to do image wise data preprocessing using the function `image_preprocessing(...)`. Note that the images shall have the size of 8x8 pixels and be flattened subsequent to the resizing. Therefore be mindfull of argument passing between the two functions!

# %%
def load_features_labels(folder,size=(64,32),flatten=True,color=False,identifiers=['NS', 'MS', 'MC', 'C']):
  features=[]
  labels=[]
  for path in glob.glob(folder+'/*.JPG'):

    if any(identifier in path for identifier in identifiers): 
      labels.append(get_label_from_name(path))
      img=cv2.imread(path)
      img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
      img=image_preprocessing(img,size,flatten,color)
      features.append(img)

  return features, labels

# %%
################
# Quality gate #
################

features, labels = load_features_labels("./data/top", size=(8,8), flatten=True, color=False)
quality_gate_112(features, labels)
# Out:
# 'Quality gate passed :)'

# %% [markdown]
# ## Section 1.2: First data analysis
# Before diving into machine learning, we'll have a look at the data. With the snippet below you can visualize a sample of the image data available in this lab. It can be observed that the class *missing cover* is rather distinct to the remaining classes, as the large black plastic cover is missing, exposing the copper wires. The defect *missing screw* is definitely harder to spot as the screws are rather small objects and the color difference between the screw and the empty hole is rather subtle. Finally, the defect *not screwed* can only be seen as some of the screws are not in the shade of the respective hole, thus indicating they are not screwed in all the way.

# %%
from mpl_toolkits.axes_grid1 import ImageGrid

fig = plt.figure(figsize=(12,12))
grid =ImageGrid(fig,
                111,# same as subplot(111)
                nrows_ncols=(3,4),
                axes_pad=(0.1,0.3))

features, labels = load_features_labels("./data/top", size=(1024, 1024), flatten=False, color=True)

classes=['Complete','Missing cover','Missing screw','Not screwed']
for i,ax in enumerate(grid):

  selectedClass=classes[i%len(classes)]
  images=np.array(features)[np.array(labels)==selectedClass]
  image=images[i//len(classes)]
  ax.imshow(image) #ax.imshow(image,cmap='gray')
  ax.set_title(selectedClass)

plt.show()
##shows the image 2D with its default colormap, so use cmap='gray' when dealing with matplotlib show

# %%
from collections import Counter
distribution= Counter(labels)
freq=distribution.values()
class_name=distribution.keys()

# %% [markdown]
# First, let's investigate the distribution of the available images among the classes.
#
# >**Task:** Please create a plot showing the distribution of the different classes and discuss the distribution in the field below.

# %%
#############################
# Please add your code here #
#############################
import math
fig=plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.scatter(class_name,freq)
plt.subplot(1,2,2)
plt.hist(labels)
# Out:
# (array([22.,  0.,  0., 47.,  0.,  0., 42.,  0.,  0.,  6.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# >**Question:** Please discuss the class distribution. Which issues and challenges might appear during model training?

# %% [markdown]
# >**Your answer:** <span style="color:green">TBD</span>

# %% [markdown]
# >**Feedback:** <span style="color:orange">...</span>

# %% [markdown]
# ## Section 1.3: Image classification using Support Vector Machines
# In this section, we'll use Support Vector Machines (SVM) to try classifying the image dataset. For SVMs, it is necessary to have the data formatted as 1D vector. Also, as mentioned in the description we are only going to consider the three classes *complete*, *missing cover*, and *missing screws*.

# %%
np.array(features).shape
# Out:
# (117, 1024, 1024, 3)

# %%
features,labels=load_features_labels("./data/top", size=(16,16), color=True, flatten=True, identifiers=['MC', 'MS', 'C'])# flatten and resize
features=np.asarray(features)
labels=np.asarray(labels)

# %%
print('Shape of feature vector: ',features.shape)
print('Shape of label vector: ', labels.shape)
# Out:
# Shape of feature vector:  (70, 768)
# Shape of label vector:  (70,)

# %%
features, labels = load_features_labels("./data/top", size=(16,16), color=True, flatten=True, identifiers=['MC', 'MS', 'C'])
features = np.asarray(features)
labels = np.asarray(labels)
print("Shape feature vector:", features.shape)
print("Shape label vector:", labels.shape)
# Out:
# Shape feature vector: (70, 768)
# Shape label vector: (70,)

# %% [markdown]
# As we can see, we still load our 117 images, but the pixel values are now simply reshaped to 1D.
# Next, we need to separate our data into training and testing datasets. This can be achieved using the `train_test_split()` function from sklearn. You can find the documentation here: [Link](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html).
#
# >**Task:** Fill in the following code so that 70% of the data is used for training, and the remaining 30% for testing. Also, the datasets should be stratified by the label vector.

# %%
from sklearn.model_selection import train_test_split

X_train,X_test, y_train,y_test= train_test_split(features,labels, test_size=0.3,random_state=42)

################
# Quality gate #
################
quality_gate_13(X_train, X_test)
# Out:
# 'Quality gate passed :)'

# %%
from sklearn.svm import SVC # you can use SVR for regression and Linear SVC for 2 classes
from sklearn.utils.class_weight import compute_sample_weight

clf= SVC(kernel="rbf",C=0.0003,gamma=0.01)
clf.fit(X_train,y_train, sample_weight=compute_sample_weight('balanced',y_train))
clf.score(X_test,y_test)
# Out:
# 0.38095238095238093

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
cm= confusion_matrix(y_test,clf.predict(X_test))
ax=sns.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Actual')
print(classification_report(y_test, clf.predict(X_test)))
# Out:
#                precision    recall  f1-score   support
#
#      Complete       0.00      0.00      0.00         1
# Missing cover       0.38      1.00      0.55         8
# Missing screw       0.00      0.00      0.00        12
#
#      accuracy                           0.38        21
#     macro avg       0.13      0.33      0.18        21
#  weighted avg       0.15      0.38      0.21        21
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Section 1.4: Image classification with artificial neural networks
#
# In this section, we will train our first artificial neural network (ANN) for image classification.
# First, we will have a look at normal ANNs. These consist of multiple dense layers which can analyze one-dimensional feature vectors. Thus, we need to reshape our 2.5-dimensional image data to 1D using the `flatten` option we integrated into our preprocessing function.
#
# ### a) Image classification using fully connected ANNs
# Again, we need to load the data using the `flatten=True` flag to convert the 2.5D data to 1D.

# %%
features, labels = load_features_labels("./data/top", size=(128,128), color=True, flatten=True, identifiers=['MC', 'MS', 'C'])
features = np.asarray(features)
labels = np.asarray(labels)
print("Shape feature vector:", features.shape)
print("Shape label vector:", labels.shape)
# Out:
# Shape feature vector: (70, 49152)
# Shape label vector: (70,)

# %% [markdown]
# >**Task:** Fill in the following code so that 70% of the data is used for training, and the remaining 30% for testing. Also the datasets should be stratified by the label vector.

# %%
X_train,X_test,y_train,y_test=train_test_split(features,labels,test_size=0.3,random_state=42)

# %% [markdown]
# The labels need to be *one hot encoded*. In one hot encoding, categorical values are transformed into a binary representation.
#
# ![OneHotEncoding](https://github.com/Vipinkthomas/Machin-Leaning-Resources/blob/SVM_CNN/img/OneHotEncoder.png?raw=1)

# %%
# The sklearn preprocessing library contains a variety of useful data preprocessing tools such as one hot encoding
from sklearn.preprocessing import OneHotEncoder
# Display the first label before encoding
print("Label of first sample before OneHot encoding:", y_train[0])
# Create the encoder object
enc = OneHotEncoder(sparse=False) # Generate Encoder
# With the fit_transform function, the encoder is fitted to the existing labels and transforms the dataset into its binary representation
y_train = enc.fit_transform(y_train.reshape(-1, 1))
# Display the first label after encoding
print("Label of first sample after OneHot encoding:", y_train[0])
# Data preprocessing should always be fitted on the training dataset, but applied to both, the training and the testing dataset. Thus the fit_transform function is only applied to the training dataset, while the the test dataset is transformed using the transform function and the fitted preprocessing module
y_test = enc.transform(y_test.reshape(-1, 1))
# Out:
# Label of first sample before OneHot encoding: Missing cover
# Label of first sample after OneHot encoding: [0. 1. 0.]

# %% [markdown]
# Now, let's define a simple ANN with an input layer, 3 hidden layer and one output layer.
# In this lab we use the **keras** library to model the neural network.
#
# A simple ANN with multiple sequential layers can be created using the `Sequential()` model. Afterwards, various layers can be added to the model through the command `model.add(LAYER)` with *LAYER* defining the layer to be added. In the first layer, the shape of the input needs to be specified using the parameter `input_shape`. This is only necessary in the first, but not in consecutive layers.
#
# Please have a look at the keras documentation regarding the [sequential model](https://keras.io/api/models/sequential/) and the [various layers](https://keras.io/api/layers/). For now, especially the core layers [Dense](https://keras.io/api/layers/core_layers/dense/) and [Activation](https://keras.io/api/layers/core_layers/activation/) are of interest.

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Input, Dropout

model = Sequential()
model.add(Dense(32, input_shape = X_train[0].shape))
model.add(Activation("relu"))
model.add(Dense(16))
model.add(Activation("relu"))
model.add(Dense(y_train[0].shape[0]))
model.add(Activation("softmax"))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                1572896
#
#  activation (Activation)     (None, 32)                0
#
#  dense_1 (Dense)             (None, 16)                528
#
#  activation_1 (Activation)   (None, 16)                0
#
#  dense_2 (Dense)             (None, 3)                 51
#
#  activation_2 (Activation)   (None, 3)                 0
#
# =================================================================
# Total params: 1,573,475
# Trainable params: 1,573,475
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Once the model is created, `model.summary()` displays the architecture of the model. You can see that the created model consists of three *dense* layers, each with an *activation* function. Also, the parameter for each layer are visible. Depending on the selected image size during preprocessing, the input vector might be rather large, thus the high number of parameters in the first dense layer.
#
# Next, the model needs to be compiled using a `loss` function and an `optimizer`. The loss function defines how the loss is computed during model training, while the optimizer defines how the weights need to be adjusted during backpropagation. You can find more information regarding the available losses [here](https://keras.io/api/losses/) and regarding the optimizers [here](https://keras.io/api/optimizers/).

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])

# %% [markdown]
# Now, the model can be trained using the datasets defined before.

# %%
model.fit(X_train, y_train, epochs = 50, batch_size = 8, validation_split=0.2, verbose = 1)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 1s 62ms/step - loss: 977.1298 - accuracy: 0.2564 - val_loss: 706.2437 - val_accuracy: 0.5000
# Epoch 2/50
# 5/5 [==============================] - 0s 22ms/step - loss: 504.5570 - accuracy: 0.4615 - val_loss: 447.8985 - val_accuracy: 0.5000
# Epoch 3/50
# 5/5 [==============================] - 0s 16ms/step - loss: 236.7457 - accuracy: 0.6154 - val_loss: 217.5187 - val_accuracy: 0.4000
# Epoch 4/50
# 5/5 [==============================] - 0s 16ms/step - loss: 184.5351 - accuracy: 0.6410 - val_loss: 84.4700 - val_accuracy: 0.4000
# Epoch 5/50
# 5/5 [==============================] - 0s 16ms/step - loss: 95.4995 - accuracy: 0.6154 - val_loss: 200.8162 - val_accuracy: 0.5000
# Epoch 6/50
# 5/5 [==============================] - 0s 16ms/step - loss: 90.2632 - accuracy: 0.8205 - val_loss: 114.9426 - val_accuracy: 0.7000
# Epoch 7/50
# 5/5 [==============================] - 0s 19ms/step - loss: 58.9103 - accuracy: 0.8205 - val_loss: 192.5406 - val_accuracy: 0.5000
# Epoch 8/50
# 5/5 [==============================] - 0s 20ms/step - loss: 22.0283 - accuracy: 0.7949 - val_loss: 45.1050 - val_accuracy: 0.6000
# Epoch 9/50
# 5/5 [==============================] - 0s 42ms/step - loss: 6.1056 - accuracy: 0.9487 - val_loss: 114.2852 - val_accuracy: 0.5000
# Epoch 10/50
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 258.0620 - val_accuracy: 0.5000
# Epoch 11/50
# 5/5 [==============================] - 0s 36ms/step - loss: 5.0090 - accuracy: 0.9487 - val_loss: 106.5178 - val_accuracy: 0.6000
# Epoch 12/50
# 5/5 [==============================] - 0s 30ms/step - loss: 3.8734 - accuracy: 0.9231 - val_loss: 125.4262 - val_accuracy: 0.5000
# Epoch 13/50
# 5/5 [==============================] - 0s 31ms/step - loss: 11.8679 - accuracy: 0.9744 - val_loss: 244.5896 - val_accuracy: 0.5000
# Epoch 14/50
# 5/5 [==============================] - 0s 51ms/step - loss: 14.1829 - accuracy: 0.9487 - val_loss: 38.5844 - val_accuracy: 0.6000
# Epoch 15/50
# 5/5 [==============================] - 0s 29ms/step - loss: 3.6659 - accuracy: 0.9487 - val_loss: 78.4806 - val_accuracy: 0.5000
# Epoch 16/50
# 5/5 [==============================] - 0s 34ms/step - loss: 3.8842e-05 - accuracy: 1.0000 - val_loss: 265.3381 - val_accuracy: 0.5000
# Epoch 17/50
# 5/5 [==============================] - 0s 33ms/step - loss: 7.2835 - accuracy: 0.9231 - val_loss: 86.2380 - val_accuracy: 0.5000
# Epoch 18/50
# 5/5 [==============================] - 0s 43ms/step - loss: 13.7625 - accuracy: 0.8718 - val_loss: 236.4502 - val_accuracy: 0.5000
# Epoch 19/50
# 5/5 [==============================] - 0s 38ms/step - loss: 8.6785 - accuracy: 0.9231 - val_loss: 171.1382 - val_accuracy: 0.5000
# Epoch 20/50
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 171.4858 - val_accuracy: 0.6000
# Epoch 21/50
# 5/5 [==============================] - 0s 28ms/step - loss: 14.7637 - accuracy: 0.8718 - val_loss: 298.4696 - val_accuracy: 0.5000
# Epoch 22/50
# 5/5 [==============================] - 0s 33ms/step - loss: 4.1382 - accuracy: 0.9744 - val_loss: 112.1084 - val_accuracy: 0.6000
# Epoch 23/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 54.6655 - val_accuracy: 0.5000
# Epoch 24/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 120.7614 - val_accuracy: 0.5000
# Epoch 25/50
# 5/5 [==============================] - 0s 29ms/step - loss: 2.8789 - accuracy: 0.9231 - val_loss: 404.0179 - val_accuracy: 0.5000
# Epoch 26/50
# 5/5 [==============================] - 0s 31ms/step - loss: 3.7920 - accuracy: 0.9487 - val_loss: 164.4651 - val_accuracy: 0.5000
# Epoch 27/50
# 5/5 [==============================] - 0s 28ms/step - loss: 3.8046 - accuracy: 0.9744 - val_loss: 280.4490 - val_accuracy: 0.5000
# Epoch 28/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 188.7841 - val_accuracy: 0.6000
# Epoch 29/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 165.4302 - val_accuracy: 0.7000
# Epoch 30/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 173.6432 - val_accuracy: 0.6000
# Epoch 31/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 178.7943 - val_accuracy: 0.6000
# Epoch 32/50
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 181.8887 - val_accuracy: 0.6000
# Epoch 33/50
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 183.7486 - val_accuracy: 0.6000
# Epoch 34/50
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 185.8310 - val_accuracy: 0.5000
# Epoch 35/50
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 187.3200 - val_accuracy: 0.5000
# Epoch 36/50
# 5/5 [==============================] - 0s 43ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 188.2128 - val_accuracy: 0.5000
# Epoch 37/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 188.7483 - val_accuracy: 0.5000
# Epoch 38/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 189.0691 - val_accuracy: 0.5000
# Epoch 39/50
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 189.2613 - val_accuracy: 0.5000
# Epoch 40/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 189.3763 - val_accuracy: 0.5000
# Epoch 41/50
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 189.4450 - val_accuracy: 0.5000
# Epoch 42/50
# 5/5 [==============================] - 0s 36ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 189.4862 - val_accuracy: 0.5000
# Epoch 43/50
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 189.5107 - val_accuracy: 0.5000
# Epoch 44/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 189.5254 - val_accuracy: 0.5000
# Epoch 45/50
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 189.5340 - val_accuracy: 0.5000
# Epoch 46/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 189.5393 - val_accuracy: 0.5000
# Epoch 47/50
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 189.5423 - val_accuracy: 0.5000
# Epoch 48/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 189.5442 - val_accuracy: 0.5000
# Epoch 49/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 189.5453 - val_accuracy: 0.5000
# Epoch 50/50
# 5/5 [==============================] - 0s 34ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 189.5459 - val_accuracy: 0.5000

# %% [markdown]
# You can use the following function to evaluate your model.

# %%
def evaluate_model(X_test, y_test, model):
    import seaborn as sns
    from sklearn.metrics import confusion_matrix, classification_report
    
    y_pred = model.predict(X_test)
    res = np.zeros_like(y_pred)
    for i in range(len(np.argmax(y_pred, axis=1))):
        res[i, np.argmax(y_pred,axis=1)[i]]=1
    y_pred = res
    cm = confusion_matrix(enc.inverse_transform(y_test), enc.inverse_transform(y_pred))
    ax=sns.heatmap(cm, annot=True)
    plt.xlabel('Predicted')
    plt.ylabel('Truth')
    print(classification_report(enc.inverse_transform(y_test), enc.inverse_transform(y_pred), zero_division=0))

# %%
evaluate_model(X_test, y_test, model)
# Out:
#                precision    recall  f1-score   support
#
#      Complete       0.00      0.00      0.00         1
# Missing cover       1.00      0.38      0.55         8
# Missing screw       0.67      1.00      0.80        12
#
#      accuracy                           0.71        21
#     macro avg       0.56      0.46      0.45        21
#  weighted avg       0.76      0.71      0.66        21

# %% [markdown]
# >**Question:** What behavior did you observe while training the model? How can the results be explained?

# %% [markdown]
# >**Your answer:** <span style="color:green">TBD</span>

# %% [markdown]
# >**Feedback:** <span style="color:orange">...</span>

# %% [markdown]
# ### b) Image classification using CNNs
#
# In this section, we are going to explore the usage of CNNs for the given task.
#
# ![Architecture CNN](https://github.com/Vipinkthomas/Machin-Leaning-Resources/blob/SVM_CNN/img/cnn_structure.png?raw=1)
#
# First, the data is loaded from file. As CNNs are capable and even excel on analyzing the multiple dimensional aspects of images, the images do not need to be reshaped in a one-dimensional vector. Thus, we have to set the flag `flatten` to `False`. You can see, that the shape of the loaded images is now a four-dimensional array with `(number of samples, width image, height image, color channels image)`.

# %%
features, labels = load_features_labels("./data/top", size=(512,512), color=True, flatten=False, identifiers=['MC', 'MS', 'C'])
features = np.array(features) # Datatype conversion of feature vector from list to array
labels = np.array(labels) # Datatype conversion of label vector from list to array
print("Shape feature vector:", features.shape)
print("Shape label vector:", labels.shape)
# Out:
# Shape feature vector: (70, 512, 512, 3)
# Shape label vector: (70,)

# %% [markdown]
# >**Task:** Fill in the following code so that 70% of the data is used for training, and the remaining 30% for testing. Also, the datasets should be stratified by the label vector. Furthermore, add OneHot Encoding for the labels as seen before.

# %%
#######################################
# Please complete the following lines #
#######################################

def split_data(features, labels):
    return train_test_split(features,labels,test_size=0.3,random_state=42)

def encode_data(y_train, y_test):
    y_train=enc.fit_transform(y_train.reshape(-1,1))
    y_test=enc.transform(y_test.reshape(-1,1))
    """Your code goes here"""
    return y_train, y_test


################
# Quality gate #
################

X_train, X_test, y_train, y_test = split_data(features, labels)
y_train, y_test = encode_data(y_train, y_test)
print("Label of first sample after OneHot encoding:", y_train[0])
quality_gate_141(y_train, y_test)
# Out:
# Label of first sample after OneHot encoding: [0. 1. 0.]
# 'Quality gate passed :)'

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten, Dropout, MaxPooling2D, GlobalMaxPooling2D

model = Sequential()
model.add(Conv2D(8, 5,  input_shape = X_train[0].shape, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(16, 3, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(32, 3, activation = 'relu', padding="same"))
model.add(GlobalMaxPooling2D())
model.add(Dense(32, activation = 'relu'))
model.add(Dense(y_train[0].shape[0], activation = 'softmax'))

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 512, 512, 8)       608
#
#  max_pooling2d (MaxPooling2D  (None, 256, 256, 8)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 16)      1168
#
#  max_pooling2d_1 (MaxPooling  (None, 128, 128, 16)     0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 32)      4640
#
#  global_max_pooling2d (Globa  (None, 32)               0
#  lMaxPooling2D)
#
#  dense_3 (Dense)             (None, 32)                1056
#
#  dense_4 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 7,571
# Trainable params: 7,571
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from tensorflow.keras.optimizers import Adam
optimizer=Adam(learning_rate=0.001)
model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy'])

# %%
model.fit(np.array(X_train), np.array(y_train), epochs = 75, batch_size = 32, validation_split=0.1, 
          verbose = 1, sample_weight=compute_sample_weight('balanced', y_train))
# Out:
# Epoch 1/75
# 2/2 [==============================] - 12s 3s/step - loss: 74.6968 - accuracy: 0.5909 - val_loss: 6.0719 - val_accuracy: 0.4000
# Epoch 2/75
# 2/2 [==============================] - 9s 3s/step - loss: 14.1941 - accuracy: 0.3182 - val_loss: 4.4368 - val_accuracy: 0.0000e+00
# Epoch 3/75
# 2/2 [==============================] - 9s 3s/step - loss: 8.0025 - accuracy: 0.1818 - val_loss: 2.0471 - val_accuracy: 0.2000
# Epoch 4/75
# 2/2 [==============================] - 11s 3s/step - loss: 6.2406 - accuracy: 0.4545 - val_loss: 1.3950 - val_accuracy: 0.6000
# Epoch 5/75
# 2/2 [==============================] - 9s 3s/step - loss: 3.3977 - accuracy: 0.6364 - val_loss: 3.4319 - val_accuracy: 0.0000e+00
# Epoch 6/75
# 2/2 [==============================] - 9s 3s/step - loss: 3.8235 - accuracy: 0.2045 - val_loss: 3.5814 - val_accuracy: 0.2000
# Epoch 7/75
# 2/2 [==============================] - 9s 3s/step - loss: 2.9915 - accuracy: 0.2727 - val_loss: 2.0433 - val_accuracy: 0.2000
# Epoch 8/75
# 2/2 [==============================] - 9s 3s/step - loss: 1.4146 - accuracy: 0.5909 - val_loss: 1.4682 - val_accuracy: 0.4000
# Epoch 9/75
# 2/2 [==============================] - 9s 3s/step - loss: 1.4143 - accuracy: 0.6136 - val_loss: 1.4589 - val_accuracy: 0.4000
# Epoch 10/75
# 2/2 [==============================] - 10s 4s/step - loss: 0.8347 - accuracy: 0.6818 - val_loss: 1.3074 - val_accuracy: 0.4000
# Epoch 11/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.4622 - accuracy: 0.7273 - val_loss: 1.1112 - val_accuracy: 0.4000
# Epoch 12/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.3665 - accuracy: 0.7500 - val_loss: 1.0528 - val_accuracy: 0.4000
# Epoch 13/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.3745 - accuracy: 0.8182 - val_loss: 0.9984 - val_accuracy: 0.4000
# Epoch 14/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.3100 - accuracy: 0.8409 - val_loss: 0.9802 - val_accuracy: 0.4000
# Epoch 15/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.2743 - accuracy: 0.7727 - val_loss: 0.9358 - val_accuracy: 0.6000
# Epoch 16/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.2177 - accuracy: 0.7727 - val_loss: 0.8534 - val_accuracy: 0.4000
# Epoch 17/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.1535 - accuracy: 0.8636 - val_loss: 0.7841 - val_accuracy: 0.4000
# Epoch 18/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.1433 - accuracy: 0.9545 - val_loss: 0.9500 - val_accuracy: 0.4000
# Epoch 19/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0881 - accuracy: 0.9773 - val_loss: 1.1871 - val_accuracy: 0.4000
# Epoch 20/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.1212 - accuracy: 0.9318 - val_loss: 1.2669 - val_accuracy: 0.4000
# Epoch 21/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.1059 - accuracy: 0.9318 - val_loss: 1.1989 - val_accuracy: 0.4000
# Epoch 22/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0610 - accuracy: 0.9773 - val_loss: 1.1018 - val_accuracy: 0.4000
# Epoch 23/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0489 - accuracy: 1.0000 - val_loss: 1.0122 - val_accuracy: 0.4000
# Epoch 24/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0588 - accuracy: 0.9773 - val_loss: 1.0145 - val_accuracy: 0.4000
# Epoch 25/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0490 - accuracy: 0.9773 - val_loss: 1.0955 - val_accuracy: 0.4000
# Epoch 26/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0417 - accuracy: 0.9773 - val_loss: 1.1657 - val_accuracy: 0.4000
# Epoch 27/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0382 - accuracy: 0.9773 - val_loss: 1.2286 - val_accuracy: 0.4000
# Epoch 28/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0315 - accuracy: 1.0000 - val_loss: 1.2855 - val_accuracy: 0.4000
# Epoch 29/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0310 - accuracy: 1.0000 - val_loss: 1.3129 - val_accuracy: 0.4000
# Epoch 30/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 1.2864 - val_accuracy: 0.4000
# Epoch 31/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0244 - accuracy: 1.0000 - val_loss: 1.2350 - val_accuracy: 0.4000
# Epoch 32/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0207 - accuracy: 1.0000 - val_loss: 1.1897 - val_accuracy: 0.4000
# Epoch 33/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 1.1461 - val_accuracy: 0.4000
# Epoch 34/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 1.1091 - val_accuracy: 0.4000
# Epoch 35/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 1.0881 - val_accuracy: 0.4000
# Epoch 36/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 1.0764 - val_accuracy: 0.4000
# Epoch 37/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 1.0714 - val_accuracy: 0.4000
# Epoch 38/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0145 - accuracy: 1.0000 - val_loss: 1.0770 - val_accuracy: 0.4000
# Epoch 39/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 1.0893 - val_accuracy: 0.4000
# Epoch 40/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 1.1061 - val_accuracy: 0.4000
# Epoch 41/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0127 - accuracy: 1.0000 - val_loss: 1.1228 - val_accuracy: 0.4000
# Epoch 42/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 1.1342 - val_accuracy: 0.4000
# Epoch 43/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 1.1425 - val_accuracy: 0.4000
# Epoch 44/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 1.1490 - val_accuracy: 0.4000
# Epoch 45/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.1533 - val_accuracy: 0.4000
# Epoch 46/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.1554 - val_accuracy: 0.4000
# Epoch 47/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 1.1516 - val_accuracy: 0.4000
# Epoch 48/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 1.1446 - val_accuracy: 0.4000
# Epoch 49/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 1.1355 - val_accuracy: 0.4000
# Epoch 50/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 1.1275 - val_accuracy: 0.4000
# Epoch 51/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.1242 - val_accuracy: 0.4000
# Epoch 52/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 1.1239 - val_accuracy: 0.4000
# Epoch 53/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.1268 - val_accuracy: 0.4000
# Epoch 54/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.1307 - val_accuracy: 0.4000
# Epoch 55/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.1373 - val_accuracy: 0.4000
# Epoch 56/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 1.1411 - val_accuracy: 0.4000
# Epoch 57/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 1.1445 - val_accuracy: 0.4000
# Epoch 58/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.1455 - val_accuracy: 0.4000
# Epoch 59/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 1.1439 - val_accuracy: 0.4000
# Epoch 60/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.1403 - val_accuracy: 0.4000
# Epoch 61/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 1.1360 - val_accuracy: 0.4000
# Epoch 62/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.1304 - val_accuracy: 0.4000
# Epoch 63/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.1268 - val_accuracy: 0.4000
# Epoch 64/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 1.1247 - val_accuracy: 0.4000
# Epoch 65/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 1.1242 - val_accuracy: 0.4000
# Epoch 66/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 1.1246 - val_accuracy: 0.4000
# Epoch 67/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.1260 - val_accuracy: 0.4000
# Epoch 68/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 1.1248 - val_accuracy: 0.4000
# Epoch 69/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 1.1238 - val_accuracy: 0.4000
# Epoch 70/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.1215 - val_accuracy: 0.4000
# Epoch 71/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 1.1197 - val_accuracy: 0.4000
# Epoch 72/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.1185 - val_accuracy: 0.4000
# Epoch 73/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.1171 - val_accuracy: 0.4000
# Epoch 74/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.1175 - val_accuracy: 0.4000
# Epoch 75/75
# 2/2 [==============================] - 9s 3s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.1199 - val_accuracy: 0.4000

# %% [markdown]
# Evaluate the trained CNN

# %%
evaluate_model(X_test, y_test, model)
# Out:
#                precision    recall  f1-score   support
#
#      Complete       0.00      0.00      0.00         1
# Missing cover       0.70      0.88      0.78         8
# Missing screw       0.78      0.58      0.67        12
#
#      accuracy                           0.67        21
#     macro avg       0.49      0.49      0.48        21
#  weighted avg       0.71      0.67      0.68        21

# %% [markdown]
# >**Question:**
# >- How does the CNN perform compared to the ANN?
# >- What could be reasons for the different performances?

# %% [markdown]
# >**Your answer:** <span style="color:green">TBD</span>

# %% [markdown]
# >**Feedback:** <span style="color:orange">...</span>

# %% [markdown]
# >**Task:**
# >With the above starter code, a first improvement in accuracy compared to the SVM and the ANN using only Dense layers should be visible. However, the network could be further improved by adjusting the hyperparameters. Below you can find the full snippet from data preprocessing to model training. Play around with the parameters and see whether you can find a model that shows an even better performance!
# >
# >Some ideas are:
# >- Explore different sized images (smaller/larger)
# >- How do black and white images compare to the rgb ones?
# >- Adapt the architecture of the neural network:
# > - Change the amount of Conv2D layers
# > - Change the number of filters in each layer
# > - Explore other activation functions
# >- Change the learning rate of the optimizer or look at different optimizers all together
# >- Train the model for more epochs
# >
# >**For comparability, please don't change the ratios for train/test and train/validation!**

# %%
np.random.seed(28)

####################################################
# Please modify the following lines                #
# ! Don't change training/test/validation ratios ! #
####################################################

# Data preprocessing
features, labels = load_features_labels("./data/top", size=(512,512), color=True, flatten=False, identifiers=['MC', 'MS', 'C'])
features = np.array(features) # Datatype conversion of feature vector from list to array
labels = np.array(labels) # Datatype conversion of label vector from list to array
X_train, X_test, y_train, y_test = split_data(features, labels) # Split features and labels into training and testing datasets
y_train, y_test = encode_data(y_train, y_test) # Encode labels

# Model definition
model = Sequential()
model.add(Conv2D(4, 5,  input_shape = X_train[0].shape, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(8, 3, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(8, 3, activation = 'relu', padding="same"))
model.add(GlobalMaxPooling2D())
model.add(Dense(8, activation = 'relu'))
model.add(Dense(y_train[0].shape[0], activation = 'softmax'))

# Model compilation
optimizer=Adam(learning_rate=0.0005)
model.compile(loss = 'categorical_crossentropy', optimizer = optimizer, metrics = ['accuracy'])

# Model training
model.fit(np.array(X_train), np.array(y_train), epochs = 50, batch_size = 2, validation_split=0.1, 
          verbose = 1, sample_weight=compute_sample_weight('balanced', y_train))

# Model evaluation
evaluate_model(X_test, y_test, model)
# Out:
# Epoch 1/50
# 22/22 [==============================] - 10s 410ms/step - loss: 23.4734 - accuracy: 0.1136 - val_loss: 16.7839 - val_accuracy: 0.2000
# Epoch 2/50
# 22/22 [==============================] - 9s 407ms/step - loss: 14.6238 - accuracy: 0.2273 - val_loss: 13.2481 - val_accuracy: 0.2000
# Epoch 3/50
# 22/22 [==============================] - 9s 403ms/step - loss: 10.2460 - accuracy: 0.2500 - val_loss: 10.3904 - val_accuracy: 0.2000
# Epoch 4/50
# 22/22 [==============================] - 9s 405ms/step - loss: 7.2725 - accuracy: 0.3182 - val_loss: 5.6516 - val_accuracy: 0.2000
# Epoch 5/50
# 22/22 [==============================] - 9s 399ms/step - loss: 7.4396 - accuracy: 0.2727 - val_loss: 5.0392 - val_accuracy: 0.2000
# Epoch 6/50
# 22/22 [==============================] - 9s 404ms/step - loss: 4.1920 - accuracy: 0.3864 - val_loss: 4.1871 - val_accuracy: 0.2000
# Epoch 7/50
# 22/22 [==============================] - 9s 404ms/step - loss: 4.9819 - accuracy: 0.2727 - val_loss: 3.0039 - val_accuracy: 0.2000
# Epoch 8/50
# 22/22 [==============================] - 9s 403ms/step - loss: 4.6516 - accuracy: 0.2955 - val_loss: 4.9829 - val_accuracy: 0.2000
# Epoch 9/50
# 22/22 [==============================] - 9s 401ms/step - loss: 3.0237 - accuracy: 0.3182 - val_loss: 2.0551 - val_accuracy: 0.2000
# Epoch 10/50
# 22/22 [==============================] - 9s 400ms/step - loss: 2.1886 - accuracy: 0.3409 - val_loss: 1.7125 - val_accuracy: 0.2000
# Epoch 11/50
# 22/22 [==============================] - 9s 401ms/step - loss: 1.8123 - accuracy: 0.3182 - val_loss: 2.3727 - val_accuracy: 0.2000
# Epoch 12/50
# 22/22 [==============================] - 9s 399ms/step - loss: 1.3033 - accuracy: 0.3636 - val_loss: 2.3827 - val_accuracy: 0.2000
# Epoch 13/50
# 22/22 [==============================] - 9s 403ms/step - loss: 1.0571 - accuracy: 0.4318 - val_loss: 1.2119 - val_accuracy: 0.2000
# Epoch 14/50
# 22/22 [==============================] - 9s 401ms/step - loss: 0.7466 - accuracy: 0.5227 - val_loss: 1.5808 - val_accuracy: 0.2000
# Epoch 15/50
# 22/22 [==============================] - 9s 403ms/step - loss: 0.6839 - accuracy: 0.4773 - val_loss: 1.3157 - val_accuracy: 0.2000
# Epoch 16/50
# 22/22 [==============================] - 9s 403ms/step - loss: 0.5964 - accuracy: 0.6136 - val_loss: 1.2934 - val_accuracy: 0.2000
# Epoch 17/50
# 22/22 [==============================] - 9s 404ms/step - loss: 0.5456 - accuracy: 0.5682 - val_loss: 1.0290 - val_accuracy: 0.2000
# Epoch 18/50
# 22/22 [==============================] - 9s 406ms/step - loss: 0.5318 - accuracy: 0.6136 - val_loss: 1.0578 - val_accuracy: 0.2000
# Epoch 19/50
# 22/22 [==============================] - 9s 403ms/step - loss: 0.5111 - accuracy: 0.6364 - val_loss: 0.9740 - val_accuracy: 0.2000
# Epoch 20/50
# 22/22 [==============================] - 9s 401ms/step - loss: 0.4825 - accuracy: 0.5455 - val_loss: 1.2832 - val_accuracy: 0.2000
# Epoch 21/50
# 22/22 [==============================] - 9s 400ms/step - loss: 0.5181 - accuracy: 0.5227 - val_loss: 0.6387 - val_accuracy: 0.2000
# Epoch 22/50
# 22/22 [==============================] - 9s 405ms/step - loss: 0.4425 - accuracy: 0.5682 - val_loss: 0.8409 - val_accuracy: 0.2000
# Epoch 23/50
# 22/22 [==============================] - 9s 403ms/step - loss: 0.3911 - accuracy: 0.6591 - val_loss: 0.5330 - val_accuracy: 0.2000
# Epoch 24/50
# 22/22 [==============================] - 9s 400ms/step - loss: 0.3504 - accuracy: 0.7045 - val_loss: 0.8667 - val_accuracy: 0.2000
# Epoch 25/50
# 22/22 [==============================] - 9s 398ms/step - loss: 0.3374 - accuracy: 0.6818 - val_loss: 0.5042 - val_accuracy: 0.2000
# Epoch 26/50
# 22/22 [==============================] - 9s 403ms/step - loss: 0.3041 - accuracy: 0.7273 - val_loss: 0.5623 - val_accuracy: 0.2000
# Epoch 27/50
# 22/22 [==============================] - 9s 402ms/step - loss: 0.2768 - accuracy: 0.7727 - val_loss: 0.5309 - val_accuracy: 0.2000
# Epoch 28/50
# 22/22 [==============================] - 9s 399ms/step - loss: 0.2651 - accuracy: 0.7727 - val_loss: 0.4815 - val_accuracy: 0.2000
# Epoch 29/50
# 22/22 [==============================] - 9s 402ms/step - loss: 0.2544 - accuracy: 0.7727 - val_loss: 0.5119 - val_accuracy: 0.2000
# Epoch 30/50
# 22/22 [==============================] - 9s 403ms/step - loss: 0.2391 - accuracy: 0.8182 - val_loss: 0.4598 - val_accuracy: 0.2000
# Epoch 31/50
# 22/22 [==============================] - 9s 401ms/step - loss: 0.2344 - accuracy: 0.8182 - val_loss: 0.4584 - val_accuracy: 0.2000
# Epoch 32/50
# 22/22 [==============================] - 9s 405ms/step - loss: 0.2253 - accuracy: 0.8182 - val_loss: 0.4596 - val_accuracy: 0.2000
# Epoch 33/50
# 22/22 [==============================] - 9s 403ms/step - loss: 0.2179 - accuracy: 0.8636 - val_loss: 0.4258 - val_accuracy: 0.2000
# Epoch 34/50
# 22/22 [==============================] - 9s 402ms/step - loss: 0.2168 - accuracy: 0.8182 - val_loss: 0.4866 - val_accuracy: 0.2000
# Epoch 35/50
# 22/22 [==============================] - 9s 402ms/step - loss: 0.2170 - accuracy: 0.7955 - val_loss: 0.3646 - val_accuracy: 0.2000
# Epoch 36/50
# 22/22 [==============================] - 9s 401ms/step - loss: 0.2047 - accuracy: 0.8636 - val_loss: 0.4082 - val_accuracy: 0.2000
# Epoch 37/50
# 22/22 [==============================] - 9s 400ms/step - loss: 0.2010 - accuracy: 0.8864 - val_loss: 0.4102 - val_accuracy: 0.2000
# Epoch 38/50
# 22/22 [==============================] - 9s 401ms/step - loss: 0.1978 - accuracy: 0.9318 - val_loss: 0.3739 - val_accuracy: 0.2000
# Epoch 39/50
# 22/22 [==============================] - 9s 399ms/step - loss: 0.1950 - accuracy: 0.8864 - val_loss: 0.4090 - val_accuracy: 0.2000
# Epoch 40/50
# 22/22 [==============================] - 9s 401ms/step - loss: 0.1892 - accuracy: 0.9318 - val_loss: 0.3703 - val_accuracy: 0.2000
# Epoch 41/50
# 22/22 [==============================] - 9s 401ms/step - loss: 0.1854 - accuracy: 0.8864 - val_loss: 0.3940 - val_accuracy: 0.2000
# Epoch 42/50
# 22/22 [==============================] - 9s 404ms/step - loss: 0.1804 - accuracy: 0.9545 - val_loss: 0.3802 - val_accuracy: 0.2000
# Epoch 43/50
# 22/22 [==============================] - 9s 407ms/step - loss: 0.1756 - accuracy: 0.9091 - val_loss: 0.3468 - val_accuracy: 0.4000
# Epoch 44/50
# 22/22 [==============================] - 9s 402ms/step - loss: 0.1719 - accuracy: 0.9545 - val_loss: 0.3400 - val_accuracy: 0.2000
# Epoch 45/50
# 22/22 [==============================] - 9s 406ms/step - loss: 0.1678 - accuracy: 0.9545 - val_loss: 0.3333 - val_accuracy: 0.2000
# Epoch 46/50
# 22/22 [==============================] - 9s 401ms/step - loss: 0.1666 - accuracy: 0.9545 - val_loss: 0.3215 - val_accuracy: 0.4000
# Epoch 47/50
# 22/22 [==============================] - 9s 402ms/step - loss: 0.1623 - accuracy: 0.9545 - val_loss: 0.3108 - val_accuracy: 0.4000
# Epoch 48/50
# 22/22 [==============================] - 9s 407ms/step - loss: 0.1586 - accuracy: 0.9545 - val_loss: 0.2868 - val_accuracy: 0.4000
# Epoch 49/50
# 22/22 [==============================] - 9s 399ms/step - loss: 0.1557 - accuracy: 0.9545 - val_loss: 0.2598 - val_accuracy: 0.6000
# Epoch 50/50
# 22/22 [==============================] - 9s 398ms/step - loss: 0.1617 - accuracy: 0.8864 - val_loss: 0.3075 - val_accuracy: 0.6000
#                precision    recall  f1-score   support
#
#      Complete       1.00      1.00      1.00         1
# Missing cover       0.33      0.62      0.43         8
# Missing screw       0.40      0.17      0.24        12
#
#      accuracy                           0.38        21
#     macro avg       0.58      0.60      0.56        21
#  weighted avg       0.40      0.38      0.35        21

# %% [markdown]
# >**Question:** Describe your approach optimizing the hyperparameters. Which behavior did you observe?

# %% [markdown]
# ## Section 1.5: Data augmentation
#
# Data augmentation is a technique for artificially increasing the dataset without the need for additional data acquisition. The reason for this is, that most machine learning models perform better the higher the available data volume is.
#
# Data augmentation uses the principle of slight modifications to the original data to create new data, while using the labels of the existing image. As those modifications are rather small, the image as a whole is not changed by a lot and the to be identified object, or in our case image class, can still be recognized. However, the training process can be increased significantly. One can think of many variations of these slight modifications of an image. Typical examples include:
# - Random flipping of the image horizontally or vertically
# - Random rotations
# - Random shifts
# - Blurring the image
# - Adding artificially created noise
# - Cropping
# - Changes in contrast
# - Elastic deformations
#
# Below you can see some examples of the different augmentation strategies applied to our dataset
#
# #### Implementation in keras
# **Keras** includes its own procedure for image augmentation using the `ImageDataGenerator` generator. This generator offers a variety of data augmentation strategies, that are directly applied to the raw data during model training. Thus, the augmented data does not need to be stored to the disk.
#
# For this exercise, we are going to use the ImageDataGenerator from keras. Please have a look at the documentation to get familiar: https://keras.io/api/preprocessing/image/#imagedatagenerator-classData augmentation is a technique for artificially increasing the dataset without the need for additional data acquisition. The reason for this is, that most machine learning models perform better the higher the available data volume is.

# %%
# Data preprocessing
features, labels = load_features_labels("./data/top", size=(512,512), color=True, flatten=False, identifiers=['MC', 'MS', 'C'])
features = np.array(features) # Datatype conversion of feature vector from list to array
labels = np.array(labels) # Datatype conversion of label vector from list to array
X_train, X_test, y_train, y_test = split_data(features, labels) # Split features and labels into training and testing datasets
y_train, y_test = encode_data(y_train, y_test) # Encode labels

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
### Create and show data augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True)

# %%
random_index = random.randint(0, len(features)) # Randomly select one image
datagen.fit(features[[random_index]]) # Fit the image generator with the randomly selected image

# %%
# Display the random augmentations
from mpl_toolkits.axes_grid1 import ImageGrid

fig = plt.figure(figsize=(16, 12))
grid = ImageGrid(fig, 111, nrows_ncols=(3, 4), axes_pad=(0.1, 0.3))

grid[0].imshow(features[random_index])
grid[0].set_title("Original")
for i, ax in enumerate(grid[1:]):
    image = datagen.flow(features[[random_index]]).next()[0].astype(int)
    ax.imshow(image) # Plot image
plt.show()

# %%
### Run model training with given data generator
X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, train_size=0.9, stratify=y_train, random_state=21)

datagen = ImageDataGenerator(
    featurewise_center=False,
    featurewise_std_normalization=False,
    rotation_range=10,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True)

datagen.fit(np.array(X_train))

model = Sequential()
model.add(Conv2D(8, 5,  input_shape = X_train[0].shape, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(8, 5, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(16, 5, activation = 'relu', padding="same"))
model.add(MaxPooling2D())
model.add(Conv2D(16, 3, activation = 'relu', padding="same"))
model.add(GlobalMaxPooling2D())
model.add(Dense(64, activation = 'relu'))
model.add(Dense(16, activation = 'relu'))
model.add(Dense(y_train[0].shape[0], activation = 'softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])

model.fit(datagen.flow(np.array(X_train), np.array(y_train), batch_size=8), validation_data=(X_validation, y_validation),
          steps_per_epoch=len(X_train) / 8, epochs=50)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 18s 3s/step - loss: 14.6882 - accuracy: 0.2045 - val_loss: 2.4102 - val_accuracy: 0.2000
# Epoch 2/50
# 5/5 [==============================] - 22s 4s/step - loss: 1.8743 - accuracy: 0.2500 - val_loss: 1.4265 - val_accuracy: 0.2000
# Epoch 3/50
# 5/5 [==============================] - 21s 4s/step - loss: 1.1937 - accuracy: 0.2955 - val_loss: 1.7963 - val_accuracy: 0.2000
# Epoch 4/50
# 5/5 [==============================] - 13s 2s/step - loss: 1.1232 - accuracy: 0.2955 - val_loss: 1.4992 - val_accuracy: 0.2000
# Epoch 5/50
# 5/5 [==============================] - 13s 2s/step - loss: 1.0425 - accuracy: 0.2500 - val_loss: 1.1636 - val_accuracy: 0.8000
# Epoch 6/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.9094 - accuracy: 0.5000 - val_loss: 0.9655 - val_accuracy: 0.6000
# Epoch 7/50
# 5/5 [==============================] - 14s 2s/step - loss: 0.9162 - accuracy: 0.6136 - val_loss: 1.0065 - val_accuracy: 0.6000
# Epoch 8/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8848 - accuracy: 0.5909 - val_loss: 1.1143 - val_accuracy: 0.6000
# Epoch 9/50
# 5/5 [==============================] - 14s 2s/step - loss: 0.8750 - accuracy: 0.6136 - val_loss: 1.1458 - val_accuracy: 0.6000
# Epoch 10/50
# 5/5 [==============================] - 14s 2s/step - loss: 0.8820 - accuracy: 0.6136 - val_loss: 1.1238 - val_accuracy: 0.6000
# Epoch 11/50
# 5/5 [==============================] - 14s 3s/step - loss: 0.9040 - accuracy: 0.6136 - val_loss: 1.1390 - val_accuracy: 0.6000
# Epoch 12/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.8392 - accuracy: 0.6136 - val_loss: 1.1476 - val_accuracy: 0.6000
# Epoch 13/50
# 5/5 [==============================] - 14s 2s/step - loss: 0.9084 - accuracy: 0.6136 - val_loss: 1.1577 - val_accuracy: 0.6000
# Epoch 14/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8762 - accuracy: 0.6136 - val_loss: 1.0306 - val_accuracy: 0.6000
# Epoch 15/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8369 - accuracy: 0.6136 - val_loss: 0.8448 - val_accuracy: 0.6000
# Epoch 16/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.9066 - accuracy: 0.6136 - val_loss: 0.8351 - val_accuracy: 0.6000
# Epoch 17/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8945 - accuracy: 0.6136 - val_loss: 0.9898 - val_accuracy: 0.6000
# Epoch 18/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8714 - accuracy: 0.6136 - val_loss: 0.9547 - val_accuracy: 0.6000
# Epoch 19/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.9156 - accuracy: 0.6136 - val_loss: 1.0049 - val_accuracy: 0.6000
# Epoch 20/50
# 5/5 [==============================] - 14s 2s/step - loss: 0.8889 - accuracy: 0.6136 - val_loss: 1.1129 - val_accuracy: 0.6000
# Epoch 21/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8940 - accuracy: 0.6136 - val_loss: 1.0740 - val_accuracy: 0.6000
# Epoch 22/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8620 - accuracy: 0.5909 - val_loss: 1.0689 - val_accuracy: 0.6000
# Epoch 23/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.8964 - accuracy: 0.5909 - val_loss: 1.0216 - val_accuracy: 0.6000
# Epoch 24/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8573 - accuracy: 0.6136 - val_loss: 1.0042 - val_accuracy: 0.6000
# Epoch 25/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.8814 - accuracy: 0.6136 - val_loss: 0.9458 - val_accuracy: 0.6000
# Epoch 26/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8351 - accuracy: 0.6136 - val_loss: 0.9547 - val_accuracy: 0.6000
# Epoch 27/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.8964 - accuracy: 0.6136 - val_loss: 1.0263 - val_accuracy: 0.6000
# Epoch 28/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8482 - accuracy: 0.6136 - val_loss: 0.9895 - val_accuracy: 0.6000
# Epoch 29/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8821 - accuracy: 0.6136 - val_loss: 1.0036 - val_accuracy: 0.6000
# Epoch 30/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8629 - accuracy: 0.6136 - val_loss: 1.0894 - val_accuracy: 0.6000
# Epoch 31/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.8518 - accuracy: 0.6136 - val_loss: 1.1520 - val_accuracy: 0.6000
# Epoch 32/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8787 - accuracy: 0.6136 - val_loss: 0.9940 - val_accuracy: 0.6000
# Epoch 33/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8039 - accuracy: 0.6136 - val_loss: 0.9587 - val_accuracy: 0.6000
# Epoch 34/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7775 - accuracy: 0.6136 - val_loss: 1.1042 - val_accuracy: 0.6000
# Epoch 35/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8254 - accuracy: 0.6136 - val_loss: 1.0832 - val_accuracy: 0.6000
# Epoch 36/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7916 - accuracy: 0.6136 - val_loss: 1.0008 - val_accuracy: 0.6000
# Epoch 37/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.7627 - accuracy: 0.6136 - val_loss: 0.8520 - val_accuracy: 0.6000
# Epoch 38/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7504 - accuracy: 0.6136 - val_loss: 0.7910 - val_accuracy: 0.6000
# Epoch 39/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.7684 - accuracy: 0.6136 - val_loss: 0.9673 - val_accuracy: 0.6000
# Epoch 40/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7712 - accuracy: 0.6136 - val_loss: 0.9165 - val_accuracy: 0.6000
# Epoch 41/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7665 - accuracy: 0.6136 - val_loss: 0.8561 - val_accuracy: 0.6000
# Epoch 42/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7248 - accuracy: 0.6591 - val_loss: 0.9504 - val_accuracy: 0.8000
# Epoch 43/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8844 - accuracy: 0.6591 - val_loss: 0.7584 - val_accuracy: 0.6000
# Epoch 44/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8178 - accuracy: 0.6136 - val_loss: 0.6740 - val_accuracy: 0.8000
# Epoch 45/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.8498 - accuracy: 0.5682 - val_loss: 0.6986 - val_accuracy: 0.6000
# Epoch 46/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7408 - accuracy: 0.6136 - val_loss: 0.9411 - val_accuracy: 0.8000
# Epoch 47/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.7764 - accuracy: 0.6818 - val_loss: 0.6774 - val_accuracy: 0.8000
# Epoch 48/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.6492 - accuracy: 0.7045 - val_loss: 0.5505 - val_accuracy: 1.0000
# Epoch 49/50
# 5/5 [==============================] - 13s 2s/step - loss: 0.6322 - accuracy: 0.6364 - val_loss: 0.5684 - val_accuracy: 0.8000
# Epoch 50/50
# 5/5 [==============================] - 13s 3s/step - loss: 0.6008 - accuracy: 0.7500 - val_loss: 0.5948 - val_accuracy: 0.8000

# %%
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 512, 512, 8)       608
#
#  max_pooling2d_4 (MaxPooling  (None, 256, 256, 8)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 256, 256, 8)       1608
#
#  max_pooling2d_5 (MaxPooling  (None, 128, 128, 8)      0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 128, 128, 16)      3216
#
#  max_pooling2d_6 (MaxPooling  (None, 64, 64, 16)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 64, 64, 16)        2320
#
#  global_max_pooling2d_2 (Glo  (None, 16)               0
#  balMaxPooling2D)
#
#  dense_7 (Dense)             (None, 64)                1088
#
#  dense_8 (Dense)             (None, 16)                1040
#
#  dense_9 (Dense)             (None, 3)                 51
#
# =================================================================
# Total params: 9,931
# Trainable params: 9,931
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
evaluate_model(X_test, y_test, model)
# Out:
#                precision    recall  f1-score   support
#
#      Complete       0.50      1.00      0.67         1
# Missing cover       1.00      0.88      0.93         8
# Missing screw       0.92      0.92      0.92        12
#
#      accuracy                           0.90        21
#     macro avg       0.81      0.93      0.84        21
#  weighted avg       0.93      0.90      0.91        21

# %% [markdown]
# >**Question:** What behavior can be observed while training the model using the data augmentation? Did it improve?

# %% [markdown]
# >**Task & Question:** Experiment with the different data augmentation parameters, are all of them similar effective?

# %% [markdown]
# >**Your answer:** <span style="color:green">TBD</span>

# %% [markdown]
# >**Feedback:** <span style="color:orange">...</span>

# %% [markdown]
# # Section 2: Expanding the project scope
# So far, only the classes *Complete*, *Missing cover*, and *Missing screw* were investigated. Those defects are easy to observe in the top view.
# The remaining defect *Not screwed* is hardly visible in the top view. Thus, information from the side view could be used to detect this defect.
#
# >**Task:** In this last part of the exercise, you are tasked to expand the current quality monitoring solution to also detect not fully fastened screws. As mentioned above, it might be useful to investigate the side view images to achieve this purpose.
# >
# >You can approach this problem using any of the above mentioned solutions such as SVMs, ANNs or CNNs.

# %%
# Your code here
# You can use as many cells as you want, but insert them before the final task at the bottom

# %% [markdown]
# >**Question:** Please describe your approach for expanding the project scope briefly.

# %% [markdown]
# >**Your answer:** <span style="color:green">TBD</span>

# %% [markdown]
# >**Feedback:** <span style="color:orange">...</span>

# %% [markdown]
# >**Question:** What was your final prediction results? What would you do to further improve the results?

# %% [markdown]
# >**Your answer:** <span style="color:green">TBD</span>

# %% [markdown]
# >**Feedback:** <span style="color:orange">...</span>

# %% [markdown]
# >**Question:** Which challenges did you encounter while solving the problem? How did you solve those?

# %% [markdown]
# >**Your answer:** <span style="color:green">TBD</span>

# %% [markdown]
# >**Feedback:** <span style="color:orange">...</span>
